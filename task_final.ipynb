# %% [markdown]
# ## Veridion Challenge #2

# %% [markdown]
# For this challenge, I created a Named Entity Recognition (NER) model using the spaCy library. The model was trained with over 100 websites scrapped from the given URLs. The model was trained with the 'PRODUCT' entity.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import time
import json
import os

# %% [markdown]
# `avoid.txt` contains words that should be ignored when analyzing the text. The words are separated by a newline character. I chose to use a regex pattern to find the words to find because I want to match the whole word and not just a substring. (e.g. 'us' should not match 'Cirrus')

# %%
with open('avoid.txt', 'r') as f:
    avoid = f.read().splitlines()

# Compile a regex pattern to match whole words from to_avoid list
pattern_to_avoid = r"\b(?:" + "|".join(map(re.escape, avoid)) + r")\b"

# %% [markdown]
# While I was analyzing some webpages, I noticed that some of them had their product names in classes like `'product-title'` or `'product--item'`. I decided to use this information to filter out the products I wanted to use. So I created a regular expression to match these classes.
#
# `avoid_find` list contains substrings / symbols that should be avoided when searching for the product names, even if they belong to a substring (e.g. '199$' should be found because of the dollar symbol)

# %%
df = pd.read_csv("pages.csv")
urls = df["max(page)"].tolist()
pattern = re.compile(r".*(product|grid).*(title|item|image).*")
avoid_find = ["$", "€", "£", ".com", "width", "height", "depth", "©"]

# %% [markdown]
# This function downloads content from a URL using `requests` and includes error handling. It sets a custom User-Agent header and retries failed downloads after a delay (default 1 second). On success, it returns the downloaded content.

# %%
def fetch_with_delays(url, delay=1):
    # Set a custom User-Agent to mimic a browser
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36"
    }
    try:
        response = requests.get(url, headers=headers, timeout=3)
        response.raise_for_status()
        return response
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        time.sleep(delay)
    return None

# %% [markdown]
# Here, I extract the products from the websites. Firstly, I use BeautifulSoup to parse the HTML content of the response. Then, I target the elements with classes matching a pattern (`pattern` regex) and headers (h1-h6). Various filters are applied to extracted text to improve accuracy:
# - Non-empty text with multiple words
# - Avoid text matching a pattern (pattern_to_avoid)
# - Remove stop words from avoid_find list
# - Clean extra spaces
# - Keep unique entries

# %%
def extract_products(response):
    soup = BeautifulSoup(response.content, "html.parser")
    matching_elements = soup.find_all(class_=lambda x: x and pattern.search(x))

    headers = {}
    for i in range(1, 7):  # for h1 to h6
        headers[f"h{i}"] = [
            header.text.strip()
            for header in soup.find_all(f"h{i}")
            if header.text.strip()
            and len(header.text.split()) > 1
            and len(header.text.split()) < 10
            and not re.search(pattern_to_avoid, header.text, re.IGNORECASE)
        ]
    matching_elements = [
        element.text.strip()
        for element in matching_elements
        if element.text.strip()
        and len(element.text.split()) > 1
        and len(element.text.split()) < 10
        and not re.search(pattern_to_avoid, element.text, re.IGNORECASE)
    ]

    all_texts = matching_elements
    all_texts += [header for header_list in headers.values() for header in header_list]
    # split elements when \n is met
    all_texts = [
        text
        for text in all_texts
        for text in text.split("\n")
        if text.strip() and len(text.split()) > 1
    ]
    all_texts = [text for text in all_texts if not any(m in text for m in avoid_find)]

    all_texts = [re.sub(r"\s+", " ", text) for text in all_texts]
    # keep unique elements
    all_texts = list(set(all_texts))
    return all_texts

# %% [markdown]
# This function only extracts the text from a website.

# %%
def extract_text(response):
    clean_text = " ".join(BeautifulSoup(response.text, "html.parser").stripped_strings)
    # remove any newlines
    clean_text = clean_text.replace("\n", " ")
    return clean_text

# %% [markdown]
# To improve the training data, I later decided to include more websites as sources. I find all the links in the HTML page + filter out the unwanted links (`links_avoid`).
# Multiple filters are applied to the links found:
# - The links are not Null/None
# - They don't have contain any string to avoid
# - insert a `/` incase they don't have it
# - Format the final link
#
# Then, we are downloading the content from each link. A valid link is when the response is not None and it contains product entities. The first 5 links with its data will be saved.

# %%
def extract_links(response):
    soup = BeautifulSoup(response.content, "html.parser")
    links = [link.get("href") for link in soup.find_all("a")]
    domain = response.url.split("/")[2]

    links_avoid = ['javascript', 'js', 'mailto', 'tel', 'pdf', 'cart']

    if domain[0:3] != "www":
        domain = "www." + domain

    url = response.url.split("/")
    url = url[0] + "//" + url[1] + url[2]

    links = [link for link in links if link != None]
    links = [link for link in links if not any(avoid in link.lower() for avoid in links_avoid)]
    links = [link[1:] if link[0] == "/" else link for link in links]
    links = [f'{url}/{link}' for link in links if link[0:4] != "http"]

    for link in links:
        link_response = fetch_with_delays(link)
        if link_response is None:
            continue
        else: 
            products = extract_products(link_response)
            if products:
                return (link, products)
    return None

# %% [markdown]
# Now, we are going to loop throught products and see their position in the website's text.

# %%
def extract_entities(text, products):
    entities = []
    for product in products:
        finding = text
        while finding.find(product) != -1:
            starting_index = finding.find(product)
            tuple = (starting_index, starting_index + len(product), 'PRODUCT')
            entities.append(tuple)
            finding = finding[starting_index + len(product):]
    return entities

# %%
TRAIN_DATA = []
sites_visited = 0
LABELS = ['PRODUCT']

# %% [markdown]
# Most links don't work at all, so I will use the first 100 links that I can access. Firstly, I append the training data for the main link and then for its children (links that I found later). I recommend running with the `train_data.json` file in working directory because it takes a lot of time to load all of the websites.

# %%
# check if the file exists
if not os.path.exists("train_data.json"):
    for url in urls:  # Crawl first 100 URLs
        if sites_visited >= 100:
            break
        try:
            response = fetch_with_delays(url)
            if response is None:
                continue

            sites_visited += 1

            products = extract_products(response)
            text = extract_text(response)
            extra_link = extract_links(response)

            entities_main = extract_entities(text, products)
            TRAIN_DATA.append((text, {"entities": entities_main}))
            
            # print(extra_link)
            if extra_link:
                extra_text = extract_text(fetch_with_delays(extra_link[0]))
                entities_extra = extract_entities(extra_text, extra_link[1])
                TRAIN_DATA.append((extra_text, {"entities": entities_extra}))
                
        except Exception as e:
            print(f"Error processing {url}: {e}")
            continue

    with open("train_data.json", "w") as f:
        json.dump(TRAIN_DATA, f)
else:
    with open("train_data.json", "r") as f:
        TRAIN_DATA = json.load(f)
# Out:
# Error fetching https://home-buy.com.au/products/bridger-pendant-larger-lamp-metal-brass: 404 Client Error: Not Found for url: https://home-buy.com.au/products/bridger-pendant-larger-lamp-metal-brass
# Error fetching https://beckurbanfurniture.com.au/products/page/2/: HTTPSConnectionPool(host='beckurbanfurniture.com.au', port=443): Max retries exceeded with url: /products/page/2/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf892665f0>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error fetching https
HTTPSConnectionPool(host='www.kannoa.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf901fb790>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.kannoa.com/collections/all: HTTPSConnectionPool(host='www.kannoa.com', port=443): Max retries exceeded with url: /collections/all (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf901fbf40>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.kannoa.com/collections/seating: HTTPSConnectionPool(host='www.kannoa.com', port=443): Max retries exceeded with url: /collections/seating (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf901fbf70>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.kannoa.com/collections/dining-tables: HTTPSConnectionPool(host='www.kannoa.com', port=443): Max retries exceeded with url: /collections/dining-tables (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf901fb6a0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.kannoa.com/collections/chaises: HTTPSConnectionPool(host='www.kannoa.com', port=443): Max retries exceeded with url: /collections/chaises (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf902b8730>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.kannoa.com/collections/cabanas: HTTPSConnectionPool(host='www.kannoa.com', port=443): Max retries exceeded with url: /collections/cabanas (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf902b8ee0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.furnituremarts.com/products/gallery-home.aspx: HTTPSConnectionPool(host='www.furnituremarts.com', port=443): Max retries exceeded with url: /products/gallery-home.aspx (Caused by SSLError(CertificateError("hostname 'www.furnituremarts.com' doesn't match 'furnituremarts.com'")))
# Error fetching https://osmen.com.au/products/customize-cushion: HTTPSConnectionPool(host='osmen.com.au', port=443): Max retries exceeded with url: /products/customize-cushion (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7faf8845bfa0>, 'Connection to osmen.com.au timed out. (connect timeout=3)'))
# Error fetching https://www.stevenshellliving.com/products/piccolo-jug: 404 Client Error: Not Found for url: https://stevenshellliving.com/products/piccolo-jug
# Error fetching https://contempoconcepts.com/products/winndom-berkeley-iii?_pos=1&_sid=362e09ca2&_ss=r: 404 Client Error: Not Found for url: https://contempoconcepts.com/products/winndom-berkeley-iii?_pos=1&_sid=362e09ca2&_ss=r
# Error fetching https://eurolivingfurniture.com/products/746-writing-desk: HTTPSConnectionPool(host='eurolivingfurniture.com', port=443): Max retries exceeded with url: /products/746-writing-desk (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7faf884e6ce0>, 'Connection to eurolivingfurniture.com timed out. (connect timeout=3)'))
# Error fetching https://sarahellison.com.au/collections/all/products/muse: 404 Client Error: Not Found for url: https://sarahellison.com.au/collections/all/products/muse
# Error fetching https://oakspecialists.com/products/bedroom/beds/63/: 404 Client Error: Not Found for url: https://www.oakspecialists.com/products/bedroom/beds/63/
# Error fetching https://midinmod.com/products/vendetta-bookcase%20via%20@https://twitter.com/midinmod?lang=en: HTTPSConnectionPool(host='midinmod.com', port=443): Max retries exceeded with url: /products/vendetta-bookcase%20via%20@https://twitter.com/midinmod?lang=en (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0dc6451b0>, 'Connection to midinmod.com timed out. (connect timeout=3)'))
# Error fetching https://www.unclaimed-furniture.com/products/Standard-Furniture/stand/11406.html: HTTPSConnectionPool(host='www.unclaimed-furniture.com', port=443): Max retries exceeded with url: /products/Standard-Furniture/stand/11406.html (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0dc646800>, 'Connection to www.unclaimed-furniture.com timed out. (connect timeout=3)'))
# Error fetching http://www.kis-lv.com/Products/products.html: HTTPConnectionPool(host='www.kis-lv.com', port=80): Max retries exceeded with url: /Products/products.html (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fb0dc644af0>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error fetching https://wayborn.com/products/: HTTPSConnectionPool(host='wayborn.com', port=443): Read timed out. (read timeout=3)
# Error fetching https://www.bovafurniture.com/products/office/desks/page/2/: 404 Client Error: Not Found for url: https://www.bovafurniture.com/products/office/desks/page/2/
# Error fetching https://hauslondon.com/products/gift-card: HTTPSConnectionPool(host='hauslondon.com', port=443): Max retries exceeded with url: /products/gift-card (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0dc646b00>, 'Connection to hauslondon.com timed out. (connect timeout=3)'))
# Error processing https://allworldfurniture.com/products/sallie-stool&via=http://www.twitter.com/alworldfurnitur&text=Euro%20Style%20Sallie%20Accent%20Stool: string index out of range
# Error fetching https://decorium.us/products/costa-adjustable-barstool: HTTPSConnectionPool(host='decorium.us', port=443): Max retries exceeded with url: /products/costa-adjustable-barstool (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0de1033a0>, 'Connection to decorium.us timed out. (connect timeout=3)'))
# Error fetching https://www.softsquare.com//softsquare.com/: HTTPSConnectionPool(host='www.softsquare.com', port=443): Max retries exceeded with url: //softsquare.com/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf884e4e80>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.softsquare.com/pages/about-us: HTTPSConnectionPool(host='www.softsquare.com', port=443): Max retries exceeded with url: /pages/about-us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf884e44f0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.softsquare.com/#: HTTPSConnectionPool(host='www.softsquare.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb076f85cc0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.softsquare.com/#: HTTPSConnectionPool(host='www.softsquare.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb0e4591120>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.softsquare.com/#: HTTPSConnectionPool(host='www.softsquare.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb076f85e40>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.softsquare.com/: HTTPSConnectionPool(host='www.softsquare.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb076f85f90>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.rockymountain.furniture/products/jofran/15003.html: 403 Client Error: Forbidden for url: https://www.rockymountain.furniture/products/jofran/15003.html
# Error fetching https://www.statewidefurniture.com/products/Ashley-Furniture/ashley/1010494.html: 403 Client Error: Forbidden for url: https://www.statewidefurniture.com/products/Ashley-Furniture/ashley/1010494.html
# Error fetching https://huckandpeck.com/products/gift-card: 404 Client Error: Not Found for url: https://huckandpeck.com/products/gift-card
# Error processing https://najarianfurniture.com/products/roma-sofa-pebble: string index out of range
# Error fetching https://mybossfurniture.com/products/tullis-2&via=&text=Tullis%20Cream/Navy/Gray%20Medium%20Rug: HTTPSConnectionPool(host='mybossfurniture.com', port=443): Max retries exceeded with url: /products/tullis-2&via=&text=Tullis%20Cream/Navy/Gray%20Medium%20Rug (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb0dc0187c0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error fetching https://www.furnish123quadcities.com/search/products/?s=36505: HTTPSConnectionPool(host='www.furnish123quadcities.com', port=443): Max retries exceeded with url: /search/products/?s=36505 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# Error processing https://americanbackyard.com/products/gift-card: string index out of range
# Error fetching https://www.roccityfurniture.com/products/abney-4pc-set/: 404 Client Error: Not Found for url: https://www.roccityfurniture.com:443/products/abney-4pc-set
# Error fetching https://www.sutherlandfurniture.com/collections/quick-ship/products/franck-sofa-quickship: 404 Client Error: Not Found for url: https://www.sutherlandfurniture.com/collections/quick-ship/products/franck-sofa-quickship
# Error fetching https://craftassociatesfurniture.com/products/craft-associates-wool-lounge-chairs-1519: HTTPSConnectionPool(host='craftassociatesfurniture.com', port=443): Max retries exceeded with url: /products/craft-associates-wool-lounge-chairs-1519 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb076f26560>, 'Connection to craftassociatesfurniture.com timed out. (connect timeout=3)'))
# Error processing https://huset-shop.com/products/gift-card: string index out of range
# Error fetching https://www.scotmeachamwoodhome.com/products/hodges-tweed: HTTPSConnectionPool(host='www.scotmeachamwoodhome.com', port=443): Max retries exceeded with url: /products/hodges-tweed (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf5d34b4f0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Error fetching https://sika-design.com/pages/retailers-and-partners: HTTPSConnectionPool(host='sika-design.com', port=443): Max retries exceeded with url: /pages/retailers-and-partners (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb07708cf40>, 'Connection to sika-design.com timed out. (connect timeout=3)'))
# Error fetching https://sika-design.com/pages/catalogues: HTTPSConnectionPool(host='sika-design.com', port=443): Max retries exceeded with url: /pages/catalogues (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb07708cc40>, 'Connection to sika-design.com timed out. (connect timeout=3)'))
# Error fetching https://sika-design.com/pages/press-info: HTTPSConnectionPool(host='sika-design.com', port=443): Max retries exceeded with url: /pages/press-info (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb07708d720>, 'Connection to sika-design.com timed out. (connect timeout=3)'))
# Error processing https://sika-design.com/products/belladonna-nature: 'NoneType' object has no attribute 'text'
# Error fetching https://thebellacottage.com/: HTTPSConnectionPool(host='thebellacottage.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0dcc9ebf0>, 'Connection to thebellacottage.com timed out. (connect timeout=3)'))
# Error fetching https://thebellacottage.com/account/login: HTTPSConnectionPool(host='thebellacottage.com', port=443): Max retries exceeded with url: /account/login (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0dcc9cdc0>, 'Connection to thebellacottage.com timed out. (connect timeout=3)'))
# Error fetching https://thebellacottage.com/: HTTPSConnectionPool(host='thebellacottage.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0dcc9d840>, 'Connection to thebellacottage.com timed out. (connect timeout=3)'))
# Error fetching https://thebellacottage.com/account/login: HTTPSConnectionPool(host='thebellacottage.com', port=443): Max retries exceeded with url: /account/login (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0dcc9d210>, 'Connection to thebellacottage.com timed out. (connect timeout=3)'))
# Error fetching https://thebellacottage.com/: HTTPSConnectionPool(host='thebellacottage.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0dcc9c070>, 'Connection to thebellacottage.com timed out. (connect timeout=3)'))
# Error fetching https://thebellacottage.com/pages/ccpa-opt-out: HTTPSConnectionPool(host='thebellacottage.com', port=443): Max retries exceeded with url: /pages/ccpa-opt-out (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0e45c60e0>, 'Connection to thebellacottage.com timed out. (connect timeout=3)'))
# Error processing https://thebellacottage.com/products/barrel-bar: 'NoneType' object has no attribute 'text'
# Error fetching https://www.skandium.com/products/ch24-soft: HTTPSConnectionPool(host='www.skandium.com', port=443): Max retries exceeded with url: /products/ch24-soft (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb0de223af0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.woodwaves.com/products/gray-floating-tv-stand-entertainment-center-eco-geo-lakewood: HTTPSConnectionPool(host='www.woodwaves.com', port=443): Max retries exceeded with url: /products/gray-floating-tv-stand-entertainment-center-eco-geo-lakewood (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb0e45c7b20>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://sjotime.com/products/notch-desk: 404 Client Error: Not Found for url: https://sjotime.com/products/notch-desk
# Error fetching https://littlepartners.com/products/bentwood: 404 Client Error: Not Found for url: https://littlepartners.com/products/bentwood
# Error fetching https://jeremiahcollection.com/products/record-storage-console: HTTPSConnectionPool(host='jeremiahcollection.com', port=443): Max retries exceeded with url: /products/record-storage-console (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0de2227a0>, 'Connection to jeremiahcollection.com timed out. (connect timeout=3)'))
# Error fetching https://www.shoptorious.com/products/nova-domus-jagger-modern-dark-grey-walnut-bedroom-set: HTTPSConnectionPool(host='www.shoptorious.com', port=443): Max retries exceeded with url: /products/nova-domus-jagger-modern-dark-grey-walnut-bedroom-set (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb0e45c4400>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://thefinestore.com/products/gift-card: HTTPSConnectionPool(host='thefinestore.com', port=443): Max retries exceeded with url: /products/gift-card (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0ddbe8e20>, 'Connection to thefinestore.com timed out. (connect timeout=3)'))
# Error fetching http://oot-oot.com/products/: HTTPSConnectionPool(host='oot-oot.com', port=443): Read timed out. (read timeout=3)
# Error fetching https://lorfords.com/#main: HTTPSConnectionPool(host='lorfords.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0ddb8f220>, 'Connection to lorfords.com timed out. (connect timeout=3)'))
# Error fetching https://lorfords.com/: HTTPSConnectionPool(host='lorfords.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0ddb8c7f0>, 'Connection to lorfords.com timed out. (connect timeout=3)'))
# Error fetching https://www.arighibianchi.co.uk/collections/new-in-homepage/products/birds-coat-rack: HTTPSConnectionPool(host='www.arighibianchi.co.uk', port=443): Max retries exceeded with url: /collections/new-in-homepage/products/birds-coat-rack (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb0ddb8ee90>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://idlehands.design/products/page/2/: HTTPSConnectionPool(host='idlehands.design', port=443): Max retries exceeded with url: /products/page/2/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0de220dc0>, 'Connection to idlehands.design timed out. (connect timeout=3)'))
# Error fetching https://www.diyfurniturestore.com/products/inside-out: HTTPSConnectionPool(host='www.diyfurniturestore.com', port=443): Max retries exceeded with url: /products/inside-out (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb0805b9120>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://bastilleandsons.com.au/products/ottoman-leo: HTTPSConnectionPool(host='bastilleandsons.com.au', port=443): Max retries exceeded with url: /products/ottoman-leo (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0747d9a50>, 'Connection to bastilleandsons.com.au timed out. (connect timeout=3)'))
# Error fetching https://classicwithatwist.com.au/products/1900-bench: HTTPSConnectionPool(host='classicwithatwist.com.au', port=443): Max retries exceeded with url: /products/1900-bench (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0747d9ba0>, 'Connection to classicwithatwist.com.au timed out. (connect timeout=3)'))
# Error fetching https://apato.com.au/products/work/kobo-st-desk/: 404 Client Error: Not Found for url: https://apato.com.au/products/work/kobo-st-desk/
# ...
# Error fetching https://zenchair.co.za/products/galileo-backrest-for-outdoors: 404 Client Error: Not Found for url: https://www.zenchair.co.za/products/galileo-backrest-for-outdoors
# Error fetching https://ubikhome.co.za/products/ada-tv-stand: HTTPSConnectionPool(host='ubikhome.co.za', port=443): Max retries exceeded with url: /products/ada-tv-stand (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f
doesn't match either of '*.myshopify.com', 'myshopify.com'")))
# Error fetching https://rusteak.com/products/sofa: 404 Client Error: Not Found for url: https://www.rusteakwinebar.com/products/sofa
# Error fetching https://www.ambersfurniture.com/products/win-table: HTTPSConnectionPool(host='www.ambersfurniture.com', port=443): Max retries exceeded with url: /products/win-table (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb0ddb8ca90>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://fredericksgallery.ca/collections/bars/products/sonoma-695-064: 404 Client Error: Not Found for url: https://fredericksgallery.ca/collections/bars/products/sonoma-695-064
# Error fetching https://www.18karatstore.com/collections/new/products/argea: HTTPSConnectionPool(host='www.18karatstore.com', port=443): Max retries exceeded with url: /collections/new/products/argea (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0747ca890>, 'Connection to www.18karatstore.com timed out. (connect timeout=3)'))
# Error fetching https://mesasilla.ca/products/: HTTPSConnectionPool(host='mesasilla.ca', port=443): Read timed out. (read timeout=3)
# Error fetching https://www.herashome.com/products/462: HTTPSConnectionPool(host='www.herashome.com', port=443): Max retries exceeded with url: /products/462 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf881e5fc0>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error fetching https://minimalandmodern.ca/products/moes-home-collection-raw-city-at-large-wp-1105-37: HTTPSConnectionPool(host='minimalandmodern.ca', port=443): Max retries exceeded with url: /products/moes-home-collection-raw-city-at-large-wp-1105-37 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb0747c9bd0>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error fetching https://www.equilibriumfurnishings.com/products/abby-walnut-credenza: HTTPSConnectionPool(host='www.equilibriumfurnishings.com', port=443): Max retries exceeded with url: /products/abby-walnut-credenza (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf881e62f0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://htinteriors.ca/products/cross-bench: HTTPSConnectionPool(host='htinteriors.ca', port=443): Max retries exceeded with url: /products/cross-bench (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf902515d0>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error fetching https://designhouse.com/products/pig-bank: HTTPSConnectionPool(host='designhouse.com', port=443): Max retries exceeded with url: /products/pig-bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7faf90251870>, 'Connection to designhouse.com timed out. (connect timeout=3)'))
# Error fetching https://mildanmarket.com/products/bling-mirror-30: 404 Client Error: Not Found for url: https://mildanmarket.com/products/beads-mirror-30

# %% [markdown]
# Preparing spaCy.

# %%
# !python3 -m spacy download en_core_web_lg
# !python3 -m spacy init fill-config base_config.cfg config.cfg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 43.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /home/i/.local/lib/python3.10/site-packages (from en-core-web-lg==3.7.1) (3.7.4)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (59.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.66.2)
# Requirement already satisfied: jinja2 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.27.1)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (21.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (6.4.0)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.7.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.10)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.2)
# Requirement already satisfied: numpy>=1.19.0 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.26.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.4.8)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.3.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/i/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.9)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/i/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.6.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/i/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.11.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /home/i/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.18.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/i/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2023.11.17)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/i/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/i/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.26.18)
# Requirement already satisfied: idna<4,>=2.5 in /home/i/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.6)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/i/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/i/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/i/.local/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/i/.local/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/i/.local/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
import spacy
from spacy.util import filter_spans
from spacy.tokens import DocBin
from tqdm import tqdm


def get_spacy_doc(file, data):
    nlp = spacy.blank("en")
    db = DocBin()

    for text, annot in tqdm(data):
        doc = nlp.make_doc(text)
        annot = annot['entities']

        ents = []
        entity_indices = []

        for start, end, label in annot:
            skip_entity = False
            for idx in range(start, end):
                if idx in entity_indices:
                    skip_entity = True
                    break
            if skip_entity:
                continue

            entity_indices = entity_indices + list(range(start, end))
            try:
                span = doc.char_span(start, end, label=label, alignment_mode='strict')
            except:
                continue

            if span is None:
                err_data = str([start, end]) + "   " + str(text) + "\n"
                file.write(err_data)
            else:
                ents.append(span)

        doc.ents = filter_spans(ents)
        db.add(doc)


    return db

# %% [markdown]
# We also have a set of data for training and a set for testing

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(TRAIN_DATA, test_size=0.2)


print(len(train), len(test))

file = open("log.txt", "w")
db = get_spacy_doc(file, train)
db.to_disk("train.spacy")

db = get_spacy_doc(file, test)
db.to_disk("test.spacy")

file.close()
# Out:
# 120 30
# 100%|██████████| 120/120 [00:01<00:00, 77.76it/s]
# 100%|██████████| 30/30 [00:00<00:00, 105.79it/s]

# %% [markdown]
# It's tiiime to train the module!

# %%
# !python3 -m spacy train config.cfg --output ./output --paths.train ./train.spacy --paths.dev ./test.spacy
# Out:
# ✔ Created output directory: output
# ℹ Saving to output directory: output
# ℹ Using CPU
# ℹ To switch to GPU 0, use the option: --gpu-id 0
#
# =========================== Initializing pipeline ===========================
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00    413.33    0.00    0.00    0.00    0.00
#   1     200        754.26  22653.83    0.00    0.00    0.00    0.00
#   3     400         83.19   4255.88    1.87   17.65    0.99    0.02
#   5     600        125.18   3431.24    4.48   15.09    2.63    0.04
#   7     800        217.46   2921.13   12.14   30.67    7.57    0.12
#   8    1000        484.30   2753.18   17.04   22.22   13.82    0.17
#  10    1200        395.18   2291.31    7.88   50.00    4.28    0.08
#  12    1400        396.31   1761.26   18.91   14.76   26.32    0.19
#  14    1600        494.19   1961.83   26.35   23.75   29.61    0.26
#  16    1800        515.26   1589.68   20.62   38.05   14.14    0.21
#  17    2000       1005.06   1734.17   22.60   41.96   15.46    0.23
#  19    2200        527.21   1304.46   24.48   25.72   23.36    0.24
#  21    2400        648.81   1544.32   17.02   44.44   10.53    0.17
#  23    2600        908.97   1312.13   19.51   37.74   13.16    0.20
#  24    2800       6671.67   1238.80   25.11   35.54   19.41    0.25
#  26    3000        623.16   1326.64   29.63   33.90   26.32    0.30
#  28    3200        608.83   1121.36   16.67   45.59   10.20    0.17
#  30    3400        771.24   1177.02   25.05   37.75   18.75    0.25
#  32    3600       1331.44    987.86   29.39   44.08   22.04    0.29
#  33    3800        993.21   1237.47   11.11   90.00    5.92    0.11
#  35    4000       1523.91   1191.20   22.33   40.17   15.46    0.22
#  37    4200       1349.43    818.20   31.86   38.25   27.30    0.32
#  39    4400       4110.13   1059.72   11.24   55.88    6.25    0.11
#  41    4600       4822.15   1201.38   23.50   48.96   15.46    0.24
#  42    4800        825.63   1064.02   23.24   44.04   15.79    0.23
#  44    5000        946.40   1048.12   12.77   84.00    6.91    0.13
#  46    5200       5822.82    977.11   19.27   46.25   12.17    0.19
#  48    5400       1576.31    871.06   16.45   37.65   10.53    0.16
#  50    5600      19550.01   1103.14   24.77   39.29   18.09    0.25
#  51    5800       1884.36    865.44   16.62   64.44    9.54    0.17
# ✔ Saved pipeline to output directory
# output/model-last

# %% [markdown]
# Now we are looking throught the other websites to check if the module is trained.

# %%
nlp_ner = spacy.load("./output/model-best")
sites_visited = 100
for url in urls[sites_visited:]:
    try:
        response = fetch_with_delays(url)
        if response is None:
            continue
        
        print(url)
        products = extract_products(response)
        text = extract_text(response)

        doc = nlp_ner(text)
://www.shorehousefurniture.com/products/Rowe-Furniture/rowe/c396sect.html: 403 Client Error: Forbidden for url: https://www.shorehousefurniture.com/products/Rowe-Furniture/rowe/c396sect.html
# Error fetching https://www.jandjtreasuretrove.net/apps/webstore/products/show/8098794: HTTPSConnectionPool(host='www.jandjtreasuretrove.net', port=443): Max retries exceeded with url: /apps/webstore/products/show/8098794 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# Error fetching https://www.idcmn.com/products/sun-company-861013-queen-bed&source=webclient: 404 Client Error: Not Found for url: https://www.idcmn.com/products/sun-company-861013-queen-bed&source=webclient
# Error fetching https://calligarisla.com/products/living/sofas/metro/minimal-and-contemporary-modular-sofa: HTTPSConnectionPool(host='calligarisla.com', port=443): Max retries exceeded with url: /products/living/sofas/metro/minimal-and-contemporary-modular-sofa (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb04c1fb5b0>: Failed to establish a new connection: [Errno -5] No address associated with hostname'))
# Error fetching https://stealasofa.com/products/isla-gray-fabric-sectional-sofa-4249: 404 Client Error: Not Found for url: https://furniturecasalinda.com/products/isla-gray-fabric-sectional-sofa-4249
# Error fetching https://urbanfurnishing.net/products/5a-rio: 404 Client Error: Not Found for url: https://urbanfurnishing.net/products/5a-rio
# https://vancouverwoodworks.com/products/aamerica-wslcb5091
# Quality Wood Furniture PRODUCT
# Quality Wood Furniture PRODUCT
# 3000 NE Andresen Rd, Vancouver WA, 98661 PRODUCT
# Open Tuesday - Saturday 10am-6pm PRODUCT
# Sku: WSLCB5091 PRODUCT
# Sku: WSLCB5091 PRODUCT
# A-America -Collection: Westlake -Finish: PRODUCT
# 3000 NE Andresen Rd, Vancouver WA, 98661 PRODUCT
# Open Tuesday - Saturday 10am-6pm PRODUCT
# https://www.kannoa.com/products/lipa-barstool
# Lipa Barstool PRODUCT
# DINING CHAIRS PRODUCT
# - HOSPITALITY FURNITURE BLOG CONTACT US BOOK PRODUCT
# DINING CHAIRS PRODUCT
# - HOSPITALITY FURNITURE BLOG CONTACT US BOOK PRODUCT
# Plastic requires no painting and is rust-free, unlike other materials. PRODUCT
# Only the Best Materials PRODUCT
# https://furnitureoutletnc.com/products/deluxe-full-mattress
# Furniture Outlet of Wilmington PRODUCT
# Error fetching https://www.furnituremarts.com/products/gallery-home.aspx: HTTPSConnectionPool(host='www.furnituremarts.com', port=443): Max retries exceeded with url: /products/gallery-home.aspx (Caused by SSLError(CertificateError("hostname 'www.furnituremarts.com' doesn't match 'furnituremarts.com'")))
# Error fetching https://osmen.com.au/products/customize-cushion: 404 Client Error: Not Found for url: https://osmen.com.au/products/customize-cushion
# Error fetching https://www.stevenshellliving.com/products/piccolo-jug: 404 Client Error: Not Found for url: https://stevenshellliving.com/products/piccolo-jug
# https://www.thefurnituremegastore.co.uk/products/noir-80x180-cm-wall-mirror
# Staingard - Stain & Accidental Damage Additional Warranties PRODUCT
# Fabric Sofas PRODUCT
# Leather Sofas PRODUCT
# Luxury Italian Leather Sofas PRODUCT
# Vintage Leather & Harris Tweed PRODUCT
# Shelving Units Cabinets Console Tables Electric Fires & Surrounds DINING ROOM PRODUCT
# Leather Sofas PRODUCT
# Luxury Italian Leather Sofas PRODUCT
# Vintage Leather & Harris Tweed PRODUCT
# Shelving Units Cabinets Console Tables Electric Fires & Surrounds DINING ROOM DINING ROOM PRODUCT
# Leather Sofas PRODUCT
# Leather Sofas PRODUCT
# Luxury Italian Leather Sofas PRODUCT
# Vintage Leather & Harris Tweed PRODUCT
# Footstools & Benches PRODUCT
# Error fetching https://contempoconcepts.com/products/winndom-berkeley-iii?_pos=1&_sid=362e09ca2&_ss=r: 404 Client Error: Not Found for url: https://contempoconcepts.com/products/winndom-berkeley-iii?_pos=1&_sid=362e09ca2&_ss=r
# https://eurolivingfurniture.com/products/746-writing-desk
# Accent Chairs PRODUCT
# Decor Rugs PRODUCT
# Fabric Sofas PRODUCT
# Leather Sectionals PRODUCT
# Fabric Sectionals PRODUCT
# Coffee Tables Side Tables PRODUCT
# Fabric Chairs PRODUCT
# Glass Tables PRODUCT
# Black Tables PRODUCT
# Dining Table by Shape: PRODUCT
# Bar Tables PRODUCT
# https://www.efurnitureny.com/products/wardrobes-and-closets/wardrobe-closet-and-armoires
# Modern Bathroom Vanity Brands PRODUCT
# Reclining Sofa Sets PRODUCT
# Dining Seating PRODUCT
# Curios and Cabinets PRODUCT
# Error fetching https://sarahellison.com.au/collections/all/products/muse: 404 Client Error: Not Found for url: https://sarahellison.com.au/collections/all/products/muse
# Error fetching https://oakspecialists.com/products/bedroom/beds/63/: 404 Client Error: Not Found for url: https://www.oakspecialists.com/products/bedroom/beds/63/
# Error fetching https://midinmod.com/products/vendetta-bookcase%20via%20@https://twitter.com/midinmod?lang=en: 404 Client Error: Not Found for url: https://midinmod.com/products/vendetta-bookcase%20via%20@https://twitter.com/midinmod?lang=en
# Error fetching https://www.unclaimed-furniture.com/products/Standard-Furniture/stand/11406.html: 403 Client Error: Forbidden for url: https://www.unclaimed-furniture.com/products/Standard-Furniture/stand/11406.html
# Error fetching http://www.kis-lv.com/Products/products.html: HTTPConnectionPool(host='www.kis-lv.com', port=80): Max retries exceeded with url: /Products/products.html (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fb081dcd540>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error fetching https://wayborn.com/products/: 404 Client Error: Not Found for url: https://wayborn.com/products/
# Error fetching https://www.bovafurniture.com/products/office/desks/page/2/: 404 Client Error: Not Found for url: https://www.bovafurniture.com/products/office/desks/page/2/
# Error fetching https://hauslondon.com/products/gift-card: 404 Client Error: Not Found for url: https://hauslondon.com/products/gift-card
# https://allworldfurniture.com/products/sallie-stool&via=http://www.twitter.com/alworldfurnitur&text=Euro%20Style%20Sallie%20Accent%20Stool
# https://decorium.us/products/costa-adjustable-barstool
# Costa Adjustable Barstool PRODUCT
# Dining Chairs PRODUCT
# Bruso Upholstered Adjustable Barstool PRODUCT
# c110=\"\"\u003eAdjustable shelves\u003c\/li\u003e\n\u003cli class=\"ng-star-inserted\" PRODUCT
# c110=\"\"\u003eAdjustable shelves\u003c\/li\u003e\n\u003cli class=\"ng-star-inserted\" PRODUCT
# Bar Unit Barstool Bar Unit - PRODUCT
# Backless Adjustable Barstool - Grade PRODUCT
# Backless Adjustable Barstool - Grade PRODUCT
# Backless Adjustable Barstool - Grade 3","public_title":"Grade 3","options":["Grade 3"],"price":83900,"weight":0,"compare_at_price":null,"inventory_management":null,"barcode":null,"requires_selling_plan":false,"selling_plan_allocations":[]},{"id":42149243093238,"title":"Grade 4","option1":"Grade 4","option2":null,"option3":null,"sku":"13-4058B","requires_shipping":true,"taxable":true,"featured_image":null,"available":true,"name":"Oahu Modern PRODUCT
# Backless Adjustable Barstool - Grade 4","public_title":"Grade 4","options":["Grade 4"],"price":86900,"weight":0,"compare_at_price":null,"inventory_management":null,"barcode":null,"requires_selling_plan":false,"selling_plan_allocations":[]}],"images":["\/\/decorium.us\/cdn\/shop\/products\/4058B_w02-1024x856.jpg?v=1637799833","\/\/decorium.us\/cdn\/shop\/products\/4058B_w03-1024x844.jpg?v=1637799833","\/\/decorium.us\/cdn\/shop\/products\/4058B_w01-1024x794.jpg?v=1637799833"],"featured_image":"\/\/decorium.us\/cdn\/shop\/products\/4058B_w02-1024x856.jpg?v=1637799833","options":["Material Options"],"media":[{"alt":null,"id":28729769033974,"position":1,"preview_image":{"aspect_ratio":1.196,"height":856,"width":1024,"src":"\/\/decorium.us\/cdn\/shop\/products\/4058B_w02-1024x856.jpg?v=1637799833"},"aspect_ratio":1.196,"height":856,"media_type":"image","src":"\/\/decorium.us\/cdn\/shop\/products\/4058B_w02-1024x856.jpg?v=1637799833","width":1024},{"alt":null,"id":28729769066742,"position":2,"preview_image":{"aspect_ratio":1.213,"height":844,"width":1024,"src":"\/\/decorium.us\/cdn\/shop\/products\/4058B_w03-1024x844.jpg?v=1637799833"},"aspect_ratio":1.213,"height":844,"media_type":"image","src":"\/\/decorium.us\/cdn\/shop\/products\/4058B_w03-1024x844.jpg?v=1637799833","width":1024},{"alt":null,"id":28729769001206,"position":3,"preview_image":{"aspect_ratio":1.29,"height":794,"width":1024,"src":"\/\/decorium.us\/cdn\/shop\/products\/4058B_w01-1024x794.jpg?v=1637799833"},"aspect_ratio":1.29,"height":794,"media_type":"image","src":"\/\/decorium.us\/cdn\/shop\/products\/4058B_w01-1024x794.jpg?v=1637799833","width":1024}],"requires_selling_plan":false,"selling_plan_groups":[],"content":"\u003cp\u003e\u003cspan\u003e\u003cstrong\u003ePriced PRODUCT
# Modern Adjustable Barstool PRODUCT
# Modern Adjustable Barstool PRODUCT
# Leather Stool in 7 Color Options","handle":"wayne-leather-stool-in-2-sizes-and-8-color-options","description":"\u003cp\u003e\u003cmeta PRODUCT
# Shell Boucle","options":["Bar height","Shell Boucle"],"price":84900,"weight":0,"compare_at_price":null,"inventory_management":null,"barcode":null,"requires_selling_plan":false,"selling_plan_allocations":[]},{"id":41456491987107,"title":"Bar height \/ Charcoal Boucle","option1":"Bar height","option2":"Charcoal Boucle","option3":null,"sku":"112-HGSR812","requires_shipping":true,"taxable":true,"featured_image":null,"available":true,"name":"Soli Industrial Stool in 2 PRODUCT
# Leather Caramel Leather Blue Boucle Shell Boucle Charcoal Boucle Counter height / Black Leather - PRODUCT
# https://www.softsquare.com/collections/usm-haller/products/usm-haller-media-o1
# side table O118 | USM Haller PRODUCT
# Error fetching https://www.rockymountain.furniture/products/jofran/15003.html: 403 Client Error: Forbidden for url: https://www.rockymountain.furniture/products/jofran/15003.html
# Error fetching https://www.statewidefurniture.com/products/Ashley-Furniture/ashley/1010494.html: 403 Client Error: Forbidden for url: https://www.statewidefurniture.com/products/Ashley-Furniture/ashley/1010494.html
# Error fetching https://huckandpeck.com/products/gift-card: 404 Client Error: Not Found for url: https://huckandpeck.com/products/gift-card
# https://najarianfurniture.com/products/roma-sofa-pebble
# Roma - Divano Roma Furniture - Najarian Furniture PRODUCT
# Dining Chairs PRODUCT
# Curios Upholstery All Upholstery Sofas PRODUCT
# Loveseats Chairs PRODUCT
# Dining Chairs PRODUCT
# Curios Upholstery Upholstery Menu Upholstery PRODUCT
# Loveseats Chairs PRODUCT
# https://qualitywoods.com/products/qw-amish-mckee-6pc-dining-set?variant=31793708105810
# Zoom Sealy FC-44938 QSWO PRODUCT
# Lite Asbury FC-14620 QSWO PRODUCT
# Michaels Cherry OCS-113 QSWO PRODUCT
# Acres D22R00973 QSWO PRODUCT
# Asbury OCS-117 QSWO PRODUCT
# Burnt Umber FC-10748 QSWO PRODUCT
# Earthtone FC-40592 QSWO PRODUCT
# Briar FC-15743 QSWO PRODUCT
# Driftwood FC-11434 QSWO PRODUCT
# American Antique FC-48024 QSWO PRODUCT
# Cocoa OCS-122 QSWO PRODUCT
# Antique Slate FC-19852 QSWO PRODUCT
# Shadow FC-24427 QSWO PRODUCT
# Ebony FC-11047 QSWO PRODUCT
# Or, order Finish Samples PRODUCT
# Furniture Inspection PRODUCT
# Crafted Furniture: PRODUCT
# QW Amish Dining Program PRODUCT
# AMERICAN HARDWOODS PRODUCT
# AMISH HAND CRAFTED PRODUCT
# HEIRLOOM QUALITY RESULT PRODUCT
# Complete the Set PRODUCT
# Error fetching https://mybossfurniture.com/products/tullis-2&via=&text=Tullis%20Cream/Navy/Gray%20Medium%20Rug: HTTPSConnectionPool(host='mybossfurniture.com', port=443): Max retries exceeded with url: /products/tullis-2&via=&text=Tullis%20Cream/Navy/Gray%20Medium%20Rug (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb07705ba00>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error fetching https://www.furnish123quadcities.com/search/products/?s=36505: HTTPSConnectionPool(host='www.furnish123quadcities.com', port=443): Max retries exceeded with url: /search/products/?s=36505 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# https://americanbackyard.com/products/gift-card
# Porch Rockers PRODUCT
# Bernhardt Ebel Elaine PRODUCT
# Porch Rockers PRODUCT
# Error fetching https://www.roccityfurniture.com/products/abney-4pc-set/: 404 Client Error: Not Found for url: https://www.roccityfurniture.com:443/products/abney-4pc-set
# Error fetching https://www.sutherlandfurniture.com/collections/quick-ship/products/franck-sofa-quickship: 404 Client Error: Not Found for url: https://www.sutherlandfurniture.com/collections/quick-ship/products/franck-sofa-quickship
# https://craftassociatesfurniture.com/products/craft-associates-wool-lounge-chairs-1519
# https://huset-shop.com/products/gift-card
# https://www.scotmeachamwoodhome.com/products/hodges-tweed
# https://www.espasso.com/products/tearsheet/1815
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# https://sika-design.com/products/belladonna-nature
# Rocking Chair PRODUCT
# Scent Sticks PRODUCT
# Celia Headboard PRODUCT
# Alexander Teak Coffee Table PRODUCT
# James Exterior Trolley PRODUCT
# Ottoman Large PRODUCT
# Roger Stool PRODUCT
# Chain for Hanging Egg Chair PRODUCT
# Luis Bench PRODUCT
# Blues Counter Stool PRODUCT
# Marche Basket PRODUCT
# Carlo Bar Trolley PRODUCT
# Salsa Bar Stool PRODUCT
# Charlottenborg Coffee Table PRODUCT
# Healthy Animal | Large PRODUCT
# Isabell Bar Stool PRODUCT
# Anna Exterior Side Table PRODUCT
# Anna Exterior Side Table PRODUCT
# George Teak Bench PRODUCT
# George Teak Extendable Table 200/280x100 cm PRODUCT
# Lucas Teak Extendable Table 200/280X100 cm PRODUCT
# Alfred Teak Side Table PRODUCT
# Simone Stool PRODUCT
# Tangelo Lamp Shade | Extra Small PRODUCT
# Healthy Animal | Small PRODUCT
# Jute Carpet 200X300 PRODUCT
# Jute Carpet 140X200 PRODUCT
# Bedspread 240X260 cm PRODUCT
# Bedspread 240X260 cm PRODUCT
# Bedspread 240X260 cm PRODUCT
# Bedspread 240X260 cm PRODUCT
# Bedspread 240X260 cm PRODUCT
# Bedspread 240X260 cm PRODUCT
# Bedspread 240X260 cm PRODUCT
# Bedspread 200X230 cm PRODUCT
# Plaid 140X200 cm PRODUCT
# Colonial Teak Table 200x100 cm PRODUCT
# Donatello Side Table PRODUCT
# Ottoman Exterior Large PRODUCT
# Ottoman Exterior Small PRODUCT
# Victoria Exterior Round Cafe Table PRODUCT
# https://www.dimshome.com/products/eave-desk
# https://thebellacottage.com/products/barrel-bar
# Barrel Bar PRODUCT
# https://www.skandium.com/products/ch24-soft
# Only 2 left | typically dispatched within 48 hours PRODUCT
# Only 2 left | typically dispatched within 48 hours PRODUCT
# Embrace Dining Table By PRODUCT
# BK15 Dining Table PRODUCT
# CH23 Dining Chair By Carl Hansen from  £776.00 Welcome to our best Skandium Winter PRODUCT
# The Skandium story Company information Cookie policy More PRODUCT
# From Skandium PRODUCT
# https://www.woodwaves.com/products/gray-floating-tv-stand-entertainment-center-eco-geo-lakewood
# Floating TV Stand - Woodwaves - Modern PRODUCT
# Floating TV Stands. Order Now For PRODUCT
# Woodwaves Furniture PRODUCT
# 711149-711149 PRODUCT
# Dimensions: 95.25”W PRODUCT
# thou wilt light my candle: PRODUCT
# Error fetching https://sjotime.com/products/notch-desk: 404 Client Error: Not Found for url: https://sjotime.com/products/notch-desk
# https://www.puji.com/www.puji.com/products/urban-industrial-bistro-dining-table
# Error fetching https://littlepartners.com/products/bentwood: 404 Client Error: Not Found for url: https://littlepartners.com/products/bentwood
# https://jeremiahcollection.com/products/record-storage-console
# Desks Tables PRODUCT
# high and the bottom cubbies are 14” PRODUCT
# Error fetching https://www.shoptorious.com/products/nova-domus-jagger-modern-dark-grey-walnut-bedroom-set: 404 Client Error: Not Found for url: https://shoptorious.com/products/nova-domus-jagger-modern-dark-grey-walnut-bedroom-set
# https://thefinestore.com/products/gift-card
# Akari Light PRODUCT
# Akari Light PRODUCT
# Error fetching http://oot-oot.com/products/: HTTPSConnectionPool(host='oot-oot.com', port=443): Read timed out. (read timeout=3)
# https://lorfords.com/collections/the-armchair-collection/products/the-bayswater-armchair
# The Bayswater Armchair PRODUCT
# The Kingston Armchair PRODUCT
# Error fetching https://www.arighibianchi.co.uk/collections/new-in-homepage/products/birds-coat-rack: 404 Client Error: Not Found for url: https://www.arighibianchi.co.uk/collections/new-in-homepage/products/birds-coat-rack
# Error fetching https://idlehands.design/products/page/2/: 404 Client Error: Not Found for url: https://idlehands.design/products/page/2/
# Error fetching https://www.diyfurniturestore.com/products/inside-out: HTTPSConnectionPool(host='www.diyfurniturestore.com', port=443): Max retries exceeded with url: /products/inside-out (Caused by SSLError(CertificateError("hostname 'www.diyfurniturestore.com' doesn't match either of '*.myshopify.com', 'myshopify.com'")))
# https://pastperfect.sg/products/
# Antique Maps PRODUCT
# Benches & Sofas PRODUCT
# Chests of Drawers PRODUCT
# Luxury Cushions PRODUCT
# Chests of Drawers PRODUCT
# Beds (5) PRODUCT
# Boxes (16) PRODUCT
# Benches & Sofas (4) PRODUCT
# Chairs (14) PRODUCT
# Chests (10) PRODUCT
# Chests of Drawers (13) PRODUCT
# Cupboards (30) PRODUCT
# Desks (12) PRODUCT
# Tables (27) PRODUCT
# Various (16) PRODUCT
# Antique Maps (13) PRODUCT
# Luxury Cushions (19) PRODUCT
# Chests of Drawers PRODUCT
# OPENING HOURS PRODUCT
# https://bastilleandsons.com.au/products/ottoman-leo
# Rosanna Spring Serie PRODUCT
# https://classicwithatwist.com.au/products/1900-bench
# 1900 BENCH | Fermob PRODUCT
# CAPUCINE / L:106 W:53 H:90 / Fermob 0 47- PRODUCT
# CAPUCINE / L:106 W:53 H:90 / Fermob - PRODUCT
# A7-ICE MINT / L:106 W:53 H:90 / Fermob - PRODUCT
# C6-HONEY / L:106 W:53 H:90 / Fermob - PRODUCT
# Error fetching https://apato.com.au/products/work/kobo-st-desk/: 404 Client Error: Not Found for url: https://apato.com.au/products/work/kobo-st-desk/
# Error fetching https://thewoodroom.com.au/products/take-me-back: 404 Client Error: Not Found for url: https://thewoodroom.com.au/products/take-me-back
# https://thebanyantree.com.au/products/gift-card
# https://ardoutdoor.com/products/
# Canvas Aluminium PRODUCT
# Suave Upholstery PRODUCT
# Bar Chairs PRODUCT
# Bar Tables PRODUCT
# Club Chairs PRODUCT
# Coffee Tables PRODUCT
# Day Beds PRODUCT
# Dining Chairs PRODUCT
# Dining Tables PRODUCT
# Patio Heaters & Fire Pits PRODUCT
# Loveseats & Sofas PRODUCT
# Protective Covers PRODUCT
# Dekko Alea 40 PRODUCT
# Bayside Aluminum PRODUCT
# Bar Chairs PRODUCT
# Bar Tables PRODUCT
# Club Chairs PRODUCT
# Coffee Tables PRODUCT
# Day Beds PRODUCT
# Dining Chairs PRODUCT
# Dining Tables PRODUCT
# Patio Heaters & Fire Pits PRODUCT
# Loveseats & Sofas PRODUCT
# Protective Covers PRODUCT
# Bar Tables PRODUCT
# Club Chairs PRODUCT
# Coffee Tables PRODUCT
# Deep Seating PRODUCT
# Dining Chairs PRODUCT
# Dining Tables PRODUCT
# Design consultation PRODUCT
# Summer hours PRODUCT
# https://hauserstores.com/products/mesa-sofa?view=product-alt
# Mesa Sofa PRODUCT
# https://boahaus.com/products/boahaus-urban-dressing-table
# https://tabularasa-furniture.com/collections/frontpage/products/ohmm-fiesta
# Dining tables PRODUCT
# Dining Chairs PRODUCT
# Bar Stools PRODUCT
# Rugs & Stuff PRODUCT
# Dining Chairs PRODUCT
# Bar Stools PRODUCT
# Rugs & Stuff PRODUCT
# Bistro table DIA70-H75 PRODUCT
# DIA100-H75 PRODUCT
# https://livingbydesign.net.au/products/sorensen-teak-bench-seat-dining
# SORENSEN TEAK BENCH | 100CM PRODUCT
# Sorensen Teak Bench PRODUCT
# Pretty & Practical PRODUCT
# SORENSEN BAMBOO SLATTED STOOL PRODUCT
# SORENSEN BAMBOO SLATTED STOOL BUNDLE X2 PRODUCT
# https://www.living-home.co.uk/products/58-07-valencia-side-table
# Milan Side Table PRODUCT
# https://relm.com.au/products/
# Error fetching https://www.harpersproject.com/products/marble-stool: HTTPSConnectionPool(host='www.harpersproject.com', port=443): Max retries exceeded with url: /products/marble-stool (Caused by SSLError(CertificateError("hostname 'www.harpersproject.com' doesn't match either of '*.myshopify.com', 'myshopify.com'")))
# Error fetching https://www.morningstartrading.ca/pages/products/recycled-treasures-consignment-pieces/hidden-treasure: 404 Client Error: Not Found for url: https://www.morningstartrading.ca/pages/products/recycled-treasures-consignment-pieces/hidden-treasure
# https://www.bellus.com/products/
# Cloud System PRODUCT
# Footstools 25 Beds 18 Headboards 15 Chairs PRODUCT
# Charles Chic Chic Footstool PRODUCT
# Error fetching https://www.hatihome.com/products/lounge-cane: 404 Client Error: Not Found for url: https://www.hatihome.com/products/lounge-cane
# Error fetching https://www.meta44.com/products/homeland: HTTPSConnectionPool(host='www.meta44.com', port=443): Max retries exceeded with url: /products/homeland (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb0801d5f30>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error fetching https://modernkomfort.ca/products/glen: HTTPSConnectionPool(host='modernkomfort.ca', port=443): Max retries exceeded with url: /products/glen (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0801d5c00>, 'Connection to modernkomfort.ca timed out. (connect timeout=3)'))
# https://www.aarniooriginals.com/collections/shop/products/pony
# The Story of Pony PRODUCT
# https://chansfurniture.com/products/copy-of-42-tennant-brand-modern-style-beatrice-bathroom-sink-vanity-tb-9433-v42-wenge-color
# Beatrice Series PRODUCT
# Crafted from the finest select birch wood and built with solid, high-end furniture-grade construction, this vanity is not only stylish but also incredibly durable. PRODUCT
# Error fetching https://alasaw.com/products/sample-box: 404 Client Error: Not Found for url: https://alasaw.com/products/sample-box
# https://hedgehousefurniture.com/products/windsor-bed
# Windsor Bed PRODUCT
# tall x ¾” PRODUCT
# Error fetching http://www.mountainteak.com/products/designer-teak-furniture/: 404 Client Error: Not Found for url: http://www.mountainteak.com/products/designer-teak-furniture/
# Error fetching https://www.lestudiolum.com/us/products/textiles/throws/: 404 Client Error: Not Found for url: https://www.lestudiolum.com/us/products/textiles/throws/
# Error fetching https://www.ameriwoodhome.com/Products/Storage/All/: 404 Client Error: Not Found for url: https://www.ameriwoodhome.com/Products/Storage/All/
# Error fetching https://www.homeandstyle.com.sg/products/richmond-sofa-grey: 404 Client Error: Not Found for url: https://www.homeandstyle.com.sg/products/richmond-sofa-grey
# https://shop.vanillawood.com/products/plume-wallpaper
# http://modliving.com.ph/products/
# Plastic Chairs PRODUCT
# Metal Chairs PRODUCT
# Wood Chairs PRODUCT
# Leather Chair PRODUCT
# Fabric Uphosltered Chairs PRODUCT
# Barstools / High Chairs PRODUCT
# Dining Table PRODUCT
# Table Tops PRODUCT
# Table Bases PRODUCT
# Plastic Chairs (103) PRODUCT
# Metal Chairs (122) PRODUCT
# Wood Chairs (92) PRODUCT
# Table Tops (26) PRODUCT
# Table Bases (30) PRODUCT
# Dining Tables (66) PRODUCT
# Barstools / High Chairs (51) PRODUCT
# Error fetching https://curiocavern.ph/products/cow-skull: HTTPSConnectionPool(host='curiocavern.ph', port=443): Max retries exceeded with url: /products/cow-skull (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)')))
# Error fetching https://www.mossmanilahome.com/products/: HTTPSConnectionPool(host='www.mossmanilahome.com', port=443): Max retries exceeded with url: /products/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf881e4cd0>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error fetching https://oakforless.com/products/gift-card: HTTPSConnectionPool(host='oakforless.com', port=443): Max retries exceeded with url: /products/gift-card (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7faf881e4640>, 'Connection to oakforless.com timed out. (connect timeout=3)'))
# https://www.castlery.com/products/spot-shelf
# Error fetching https://www.getmycouch.com/collections/sofa/products/sofa-sectional-bed-fn-gmc-008237: HTTPSConnectionPool(host='www.getmycouch.com', port=443): Max retries exceeded with url: /collections/sofa/products/sofa-sectional-bed-fn-gmc-008237 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf881e4ca0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.castlery.com.au/products/mico-stool?quantity=1: 404 Client Error: Not Found for url: https://www.castlery.com/au/products/mico-stool?quantity=1
# Error fetching https://homestreethome.ie/products/zinc-tray: HTTPSConnectionPool(host='homestreethome.ie', port=443): Max retries exceeded with url: /products/zinc-tray (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb07fd5df90>, 'Connection to homestreethome.ie timed out. (connect timeout=3)'))
# Error fetching https://nazzek.myshopify.com/products/wooden-coffee-table: 402 Client Error: Payment Required for url: https://nazzek.myshopify.com/products/wooden-coffee-table
# https://www.myconcept.com.hk/products/moo
# Error fetching https://newforestrusticfurniture.co.uk/products/rustic-ruler-height-chart: 404 Client Error: Not Found for url: https://newforestrusticfurniture.co.uk/products/rustic-ruler-height-chart
# Error fetching https://www.starliving.com.sg/products/heather-armchair: 404 Client Error: Not Found for url: https://www.starliving.com.sg/products/heather-armchair
# https://vauntdesign.com/products/forna-plant-stand-small
# Bar Stools PRODUCT
# Error fetching https://www.langria.com/products/laptop-desk-cart: 404 Client Error: Not Found for url: https://langria.com/products/laptop-desk-cart
# Error fetching https://www.kolocollection.com/collections/lounging/products/bentley-sofa-in-oyster-weave: 404 Client Error: Not Found for url: https://www.kolocollection.com/collections/lounging/products/bentley-sofa-in-oyster-weave
# https://asianteakfurniture.com/products/bali-teak-bench-atf388
# Error fetching https://furnitica-vinova.myshopify.com/products/enim-donec-pede: HTTPSConnectionPool(host='furnitica-vinova.myshopify.com', port=443): Max retries exceeded with url: /products/enim-donec-pede (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb0819d0220>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://jordanshome.ca/products/blue-vase: 404 Client Error: Not Found for url: https://jordanshome.ca/products/blue-vase
# https://mikazahome.ca/products/page/4/
# Dining tables and bar tables PRODUCT
# Sleeping Beds PRODUCT
# Anita dining chair PRODUCT
# ANTONIO Ceiling Lamp PRODUCT
# Arc floor lamp PRODUCT
# Dining tables and bar tables PRODUCT
# Sleeping Beds PRODUCT
# https://barnabylane.com.au/products/spensley-tan
# Tanner Dining chair - Tan On PRODUCT
# Dining Chair - Tan PRODUCT
# Dining Chair - Whiskey PRODUCT
# Leather Armchairs PRODUCT
# Leather Dining Chairs PRODUCT
# Leather Chair PRODUCT
# Leather Bench Seat Leather Cushions PRODUCT
# Error fetching https://urbangalleria.com/products/rowan-pod-swing: 404 Client Error: Not Found for url: https://urbangalleria.com/products/rowan-pod-swing
# https://www.modernfurniture.com.au/collections/on-sale/products/vision-suspended-sunbed
# Dining Chairs PRODUCT
# Dining Chairs PRODUCT
# Sample Product PRODUCT
# Error fetching https://www.granitelane.com.au/products/flourish-print: 404 Client Error: Not Found for url: https://www.granitelane.com.au/products/flourish-print
# https://teak-furniture-singapore.com/products/sweden-side-table
# Sweden Teak Side Coffee Table 60 x 60 cm PRODUCT
# Product Code: PRODUCT
# https://teak-warehouse-sale.com/products/tws889lt-000-ta-lp
# Installament Plan - Latitude PRODUCT
# Installament Plan - Latitude PRODUCT
# Installament Plan - Latitude PRODUCT
# Installament Plan - Latitude PRODUCT
# https://www.countrysideamishfurniture.com/products/home-entertainment-centers/all/P40
# Dining Tables PRODUCT
# Murphy Beds PRODUCT
# Bunk Beds PRODUCT
# Changing Tables Dressers & Chests Nightstands Toy PRODUCT
# Marlette 2-Drawer Corner TV Stand PRODUCT
# Lake 3-Door TV Stand PRODUCT
# https://www.modishstore.com/products/twos-company-sunburst-antiqued-gold-wall-mirror
# Sunburst Antiqued Gold Wall Mirror PRODUCT
# Bar Tables PRODUCT
# Bar Stools PRODUCT
# Wall Decor PRODUCT
# Trophy Heads Wall Art Picture Frames Hooks & Racks PRODUCT
# Display Cases Sculptures Model Boats PRODUCT
# Display Cases Bins & Baskets Coat Racks PRODUCT
# Bar Stools PRODUCT
# Outdoor Decor PRODUCT
# Bar Tables PRODUCT
# Bar Stools PRODUCT
# Wall Decor PRODUCT
# Trophy Heads Wall Art Picture Frames Hooks & Racks PRODUCT
# Display Cases Sculptures Model Boats PRODUCT
# Display Cases Bins & Baskets Coat Racks PRODUCT
# & Buckets PRODUCT
# Bar Stools PRODUCT
# Outdoor Decor PRODUCT
# Sunburst Antiqued Gold Wall Mirror Sold out Two's Company PRODUCT
# Sunburst Antiqued Gold Wall Mirror PRODUCT
# Sunburst Antiqued Gold Wall Mirror Two's Company PRODUCT
# Sunburst Antiqued Gold Wall Mirror Two's Company PRODUCT
# Sunburst Antiqued Gold Wall Mirror - Steel/MDF/Glass PRODUCT
# Sunburst Antiqued Gold Wall PRODUCT
# Sunburst Antiqued Gold Wall PRODUCT
# Sunburst Antiqued Gold Wall Mirror PRODUCT
# Error fetching https://www.stylemyhome.com.au/products/regency-three-drawer-chest: 404 Client Error: Not Found for url: https://www.stylemyhome.com.au/products/regency-three-drawer-chest
# https://loft-theme-demo-nashville.myshopify.com/products/black-chair
# Black Chair PRODUCT
# Product photos PRODUCT
# Product highlights PRODUCT
# Error fetching https://teakco.com/products/amsterdam-2-drawer-bedside-table-tek168bs-002-ta: HTTPSConnectionPool(host='teakco.com', port=443): Max retries exceeded with url: /products/amsterdam-2-drawer-bedside-table-tek168bs-002-ta (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb07fd93370>, 'Connection to teakco.com timed out. (connect timeout=3)'))
# Error fetching https://www.skovby.com/en-gb/products/tv-cabinets/skovby-86: 404 Client Error: Not Found for url: https://www.skovby.com/en-gb/products/tv-cabinets/skovby-86
# Error fetching https://boulevardoutdoorfurniture.com/products/surin-lounge-set: 404 Client Error: Not Found for url: https://boulevardoutdoorfurniture.com/products/surin-lounge-set
# https://big-sale-furniture.com/products/amsterdam-bench-150-x-35-be-150-35-ta
# Product Code: PRODUCT
# https://taktcph.com/products/
# Stay in touch PRODUCT
# Turn Chair PRODUCT
# Cross Chair Tube PRODUCT
# Spoke Sofa PRODUCT
# Curve Coat Rack PRODUCT
# Turn Table PRODUCT
# Cross Bar Chair Tube PRODUCT
# Cross Table 120 PRODUCT
# Studio Bar Stool PRODUCT
# Error fetching https://www.nigbursfinefurniture.com/products/: HTTPSConnectionPool(host='www.nigbursfinefurniture.com', port=443): Max retries exceeded with url: /products/ (Caused by SSLError(CertificateError("hostname 'www.nigbursfinefurniture.com' doesn't match either of '*.mybigcommerce.com', 'mybigcommerce.com'")))
# Error fetching https://brownandbeam.com/products/hunts-pouf: 404 Client Error: Not Found for url: https://brownandbeam.com/products/hunts-pouf
# Error fetching https://furniturestoresalemoregon.com/products/amish-furniture/style-your-own-syo/: 404 Client Error: Not Found for url: https://furniturestoresalemoregon.com/products/amish-furniture/style-your-own-syo/
# https://www.dengiloutdoorfurniture.com/products/sofa-sets/rattan-sofa-sets/
# https://taeillo.com/products/ada
# Error fetching https://birba.co.za/products/elkay-coffee-table-with-black-resign-line-detail: HTTPSConnectionPool(host='birba.co.za', port=443): Max retries exceeded with url: /products/elkay-coffee-table-with-black-resign-line-detail (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb081dfcac0>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error fetching https://zenchair.co.za/products/galileo-backrest-for-outdoors: 404 Client Error: Not Found for url: https://www.zenchair.co.za/products/galileo-backrest-for-outdoors
# Error fetching https://ubikhome.co.za/products/ada-tv-stand: HTTPSConnectionPool(host='ubikhome.co.za', port=443): Max retries exceeded with url: /products/ada-tv-stand (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb08090d1b0>, 'Connection to ubikhome.co.za timed out. (connect timeout=3)'))
# Error fetching https://vintage-etc.com/products/tabeni-coat-stand: HTTPSConnectionPool(host='vintage-etc.com', port=443): Max retries exceeded with url: /products/tabeni-coat-stand (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb081dfd9f0>, 'Connection to vintage-etc.com timed out. (connect timeout=3)'))
# Error fetching https://www.youngath-art.com/products/free-gift-with-every-kids-bed-purchase: 404 Client Error: Not Found for url: https://www.youngath-art.com/products/free-gift-with-every-kids-bed-purchase
# Error fetching https://www.hamac-shop.be/products/hamac-brasil-xxl-vert: HTTPSConnectionPool(host='www.hamac-shop.be', port=443): Max retries exceeded with url: /products/hamac-brasil-xxl-vert (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb081dfcac0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.masayacompany.com/collections/featured/products/wood-leather-ottoman: 404 Client Error: Not Found for url: https://www.masayacompany.com/collections/featured/products/wood-leather-ottoman
# Error fetching https://ikonitaly.com/products/minimaproject-chieut-table: HTTPSConnectionPool(host='www.ikonitaly.com', port=443): Max retries exceeded with url: /products/minimaproject-chieut-table (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb081dfd4e0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://arkaliving.com/products/african-palm-woven-chair: 404 Client Error: Not Found for url: https://arkaliving.com/products/african-palm-woven-chair
# Error fetching https://www.cmphouse.com/products/huntington%E2%84%A2-8pc-patio-sofa-and-lounge-chair-set: HTTPSConnectionPool(host='www.cmphouse.com', port=443): Max retries exceeded with url: /products/huntington%E2%84%A2-8pc-patio-sofa-and-lounge-chair-set (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb080918f10>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error fetching https://inliving.com/products/: HTTPSConnectionPool(host='inliving.com', port=443): Max retries exceeded with url: /products/ (Caused by SSLError(CertificateError("hostname 'inliving.com' doesn't match either of '*.wordpress.com', 'wordpress.com'")))
# https://www.oakvillage.co.uk/products/woburn-painted-wine-rack%20via%20@//twitter.com/oakvillage
# https://waltercox.co.uk/products/
# Bunk Beds PRODUCT
# Lamp Tables Mirrors PRODUCT
# years ago and now PRODUCT
# Error fetching https://davidsfurniture.com/collections/quick-ship-furniture/products/craftmaster-bang-bang-sofa: HTTPSConnectionPool(host='davidsfurniture.com', port=443): Max retries exceeded with url: /collections/quick-ship-furniture/products/craftmaster-bang-bang-sofa (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb081d4b9a0>, 'Connection to davidsfurniture.com timed out. (connect timeout=3)'))
# http://www.diamondfurniturepremier.com/products/
# Error fetching https://www.fdxonline.com/en/en/products/chaise-lounge-by-dfn: HTTPSConnectionPool(host='www.fdxonline.com', port=443): Max retries exceeded with url: /en/en/products/chaise-lounge-by-dfn (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb081d98a60>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error fetching https://www.212concept.com/products/ikon-sofa: HTTPSConnectionPool(host='www.212concept.com', port=443): Max retries exceeded with url: /products/ikon-sofa (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb081d98160>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.stacksfurniture.co.nz/products/rapaki3seatsofa-fog: HTTPSConnectionPool(host='www.stacksfurniture.co.nz', port=443): Max retries exceeded with url: /products/rapaki3seatsofa-fog (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb081d98b20>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# https://vintagehomeboutique.ca/products/zinolin-teak-oil
# Zinolin Teak Oil PRODUCT
# Carts Ottoman/ Benches PRODUCT
# Carts Ottoman/ Benches PRODUCT
# Sideboards Dining Tables PRODUCT
# Error fetching https://bydesignmodern.com/products/dining-chairs-314-080: 404 Client Error: Not Found for url: https://bydesignmodern.com/products/dining-chairs-314-080
# https://www.couchpotatocompany.com/collections/best-sellers/products/ro-armchair
# Ro Armchair PRODUCT
# Brushed Aluminium PRODUCT
# Brushed Aluminium Legs hallingdal_light_brown / PRODUCT
# Wooden Legs hallingdal_wine_red_purple / Brushed Aluminium Legs hallingdal_wine_red_purple PRODUCT
# JH1-Aluminium, JH2-Wooden Height: 113.0 cm PRODUCT
# stock Bubble Chair PRODUCT
# Table Oval PRODUCT
# Brushed Aluminium PRODUCT
# Brushed Aluminium Legs hallingdal_light_brown / PRODUCT
# Wooden Legs hallingdal_wine_red_purple / Brushed Aluminium Legs hallingdal_wine_red_purple PRODUCT
# Error fetching https://www.bfelix.com/products/lanceros-sofa: HTTPSConnectionPool(host='www.bfelix.com', port=443): Max retries exceeded with url: /products/lanceros-sofa (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb0de2d1720>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# https://mueblesitaliano.ph/products/
# Dining Set PRODUCT
# Luxury Furniture Philippines PRODUCT
# clever use PRODUCT
# Muebles Italiano received through the years: PRODUCT
# https://www.laura-james.co.uk/products/coffee-table-corona
# Wooden Coffee Table - Laura James PRODUCT
# Garden Dining Room Living Room Bedroom Hallway Home Accessories PRODUCT
# Garden Dining Room Living Room Bedroom Hallway Home Accessories PRODUCT
# Depth (cm) 60 PRODUCT
# https://emesfurnishop.co.uk/products/ivo-wardrobe
# https://mossgardenhome.com/products/woodland-puzzle
# Furniture Clearance PRODUCT
# Outdoor Furniture PRODUCT
# Indoor Furniture PRODUCT
# Outdoor Lighting PRODUCT
# Outdoor Lighting PRODUCT
# Chilewich Mats PRODUCT
# Table Linens PRODUCT
# Pokoloko | Turkish Textiles PRODUCT
# Error fetching https://www.amcfurniture.co.uk/products/1-6m-loui-dining-table-with-4-nicole-chairs: 404 Client Error: Not Found for url: https://www.amcfurniture.co.uk/products/1-6m-loui-dining-table-with-4-nicole-chairs
# Error fetching https://timelessdesign.com.my/products/l-a-lcw-lounge-chair: 404 Client Error: Not Found for url: https://timelessdesign.com.my/products/l-a-lcw-lounge-chair
# Error fetching https://atomi.shop/products/wallpaper: 404 Client Error: Not Found for url: https://atomi.shop/products/wallpaper
# Error fetching https://www.houzzconcept.com.au/products/ino-sideboard: HTTPSConnectionPool(host='www.houzzconcept.com.au', port=443): Max retries exceeded with url: /products/ino-sideboard (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb04c1bc2b0>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# https://lesa.com.my/website2019/products/living/
# Error fetching https://kenittifurniture.com/products/tv-cabinet-mn681: HTTPSConnectionPool(host='kenittifurniture.com', port=443): Max retries exceeded with url: /products/tv-cabinet-mn681 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb07f935f30>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error fetching https://www.mfdesign.com.my/collections/sales-05/products/mf-design-sofa-3-seater-sales-05: HTTPSConnectionPool(host='www.mfdesign.com.my', port=443): Max retries exceeded with url: /collections/sales-05/products/mf-design-sofa-3-seater-sales-05 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb07f9363b0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# https://nyfurnitureoutlets.com/products/acme-furniture-versailles-classic-bed-king
# Product Description PRODUCT
# Similar Panel Bed PRODUCT
# Tundra Upholstered Sleigh Platform Bed Queen PRODUCT
# Transitional Espresso Finish Wood Panel Queen Bed Madison-19570Q Acme PRODUCT
# https://www.mydiscountmalta.com/products/mdm-wardrobe
# BBQ Bed PRODUCT
# Dyson Accessories PRODUCT
# dyson fan PRODUCT
# ...
# Error fetching https://uniquehomefurnishing.co.uk/products/hzh330: HTTPSConnectionPool(host='uniquehomefurnishing.co.uk', port=443): Max retries exceeded with url: /products/hzh330 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7faf902bd270>, 'Connection to uniquehomefurnishing.co.uk timed out. (connect timeout=3)'))
# Error fetching https://urbansize.co.uk/products/hallway-tidy: HTTPSConnectionPool(host='urbansize.co.uk', port=443): Max retries exceeded with url: /products/hallway-tidy (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7faf902bd720>, 'Connection to urbansize.co.uk timed out. (connect timeout=3)'))
# Error fetching https://www.modernfurnituredeals.co.uk/products/ovo: 404 Client Error: Not Found for url: https://www.modernfurnituredeals.co.uk/products/ovo
# Error fetching https://www.abowed.co.uk/products/oak-four-poster-bed: HTTPSConnectionPool(host='www.abowed.co.uk', port=443): Max retries exceeded with url: /products/oak-four-poster-bed (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf902bd9c0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.peterboroughreclinercentre.co.uk/products/reno-chair-with-footstool: HTTPSConnectionPool(host='www.peterboroughreclinercentre.co.uk', port=443): Max retries exceeded with url: /products/reno-chair-with-footstool (Caused by SSLError(CertificateError("hostname 'www.peterboroughreclinercentre.co.uk' doesn't match either of 'peterboroughreclinercentre.co.uk', 'legally-linked.com', 'titlemediagroup.com'")))
# Error fetching https://outletbarn.co.uk/collections/corner-sofas/products/ellena-recliner-corner-group-brown-only-limited-stock: 404 Client Error: Not Found for url: https://outletbarn.co.uk/collections/corner-sofas/products/ellena-recliner-corner-group-brown-only-limited-stock
# https://www.oaktreeupholstery.co.uk/products/double-headboard-b-fabric
# Oban Denim AquaClean PRODUCT
# Oban Denim Aquaclean PRODUCT
# Error fetching https://www.rightprice.co.uk/collections/all/products/alexis: HTTPSConnectionPool(host='www.rightprice.co.uk', port=443): Max retries exceeded with url: /collections/all/products/alexis (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb0dc56a980>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.sheridaninteriors.co.uk/products/celine-fabric-bed: HTTPSConnectionPool(host='www.sheridaninteriors.co.uk', port=443): Max retries exceeded with url: /products/celine-fabric-bed (Caused by SSLError(CertificateError("hostname 'www.sheridaninteriors.co.uk' doesn't match either of '*.myshopify.com', 'myshopify.com'")))
# Error fetching https://www.chattelsfurniture.co.uk/products/bedside-table-two-drawers: HTTPSConnectionPool(host='www.chattelsfurniture.co.uk', port=443): Max retries exceeded with url: /products/bedside-table-two-drawers (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate (_ssl.c:1007)')))
# Error fetching https://www.maisonandgarden.co.uk/products/28cm-solar-ball: 404 Client Error: Not Found for url: https://www.maisonandgarden.co.uk/products/28cm-solar-ball
# Error fetching https://igigishop.co.uk/products/cotton-rug: 404 Client Error: Not Found for url: https://igigishop.co.uk/products/cotton-rug
# Error fetching https://divine-interiors.co.uk/products/sofa-deposit: HTTPSConnectionPool(host='divine-interiors.co.uk', port=443): Max retries exceeded with url: /products/sofa-deposit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf902bf1f0>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# https://shackletonsretail.co.uk/products/
# Fabric 3 Seater Sofas PRODUCT
# Fabric 3 Seater Manual Recliner Sofas PRODUCT
# Fabric 3 Seater Power Recliner Sofas PRODUCT
# Fabric Chairs Fabric High Seat Chairs Fabric Manual Recliners Fabric Power Recliners Fabric Riser Recliners Fabric Footstools PRODUCT
# Leather 3 Seater Sofas PRODUCT
# Leather 3 Seater Manual Recliners PRODUCT
# Leather Chairs PRODUCT
# Leather Manual Recliners Leather Power PRODUCT
# Leather Footstools PRODUCT
# Leather Accessories PRODUCT
# Adjustable Bases PRODUCT
# Fabric 3 Seater Manual Recliner Sofas PRODUCT
# Fabric 3 Seater Power Recliner Sofas PRODUCT
# Fabric Chairs Fabric High Seat Chairs Fabric Manual Recliners Fabric Power Recliners Fabric Riser Recliners Fabric PRODUCT
# Leather 3 Seater Sofas PRODUCT
# Leather 3 Seater Manual Recliners PRODUCT
# Leather Chairs PRODUCT
# Leather Manual Recliners Leather Power PRODUCT
# Leather Footstools PRODUCT
# Single Adjustable Bases Small Double Adjustable Bases PRODUCT
# Adjustable Bases PRODUCT
# MATTRESSES Single Adjustable Mattress Small Double Adjustable PRODUCT
# RECLINER CHAIRS PRODUCT
# SWIVEL CHAIRS FOOTSTOOLS PRODUCT
# Error fetching https://auburnfox.co.uk/products/iron-and-leather-adjustable-stool: 404 Client Error: Not Found for url: https://www.auburnfox.co.uk/products/iron-and-leather-adjustable-stool
# Error fetching https://www.decoframe.co.uk/products/: 404 Client Error: Not Found for url: https://www.decoframe.co.uk/products/
# Error fetching https://snugathome.co.uk/products/eiffel-dining-chair: HTTPSConnectionPool(host='snugathome.co.uk', port=443): Max retries exceeded with url: /products/eiffel-dining-chair (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb0747c9060>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error fetching https://ashtonandcoleman.co.uk/products/tables/lamp-table: 404 Client Error:  for url: https://ashtonandcoleman.co.uk/products/tables/lamp-table
# https://rusticland.co.uk/products/industrial-2x-handmade-x-dining-table-bench-frame-steel-large-table-pedestal-legs
# Family? PRODUCT
# Error fetching https://www.quaysideinteriors.co.uk/products/alexandra-bed-king: 404 Client Error: Not Found for url: https://www.quaysideinteriors.co.uk/products/alexandra-bed-king
# Error fetching https://alidasa.co.uk/products/terra-6-3-drawer-pine-white: HTTPSConnectionPool(host='alidasa.co.uk', port=443): Max retries exceeded with url: /products/terra-6-3-drawer-pine-white (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb
Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb0805bba60>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://www.myharmony.hk/products/woody-slab-table: 404 Client Error: Not Found for url: https://www.myharmony.hk/404
# Error fetching https://afg.us.com/products/ashley-baraga-h410-24: HTTPSConnectionPool(host='afg.us.com', port=443): Max retries exceeded with url: /products/ashley-baraga-h410-24 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0805bb160>, 'Connection to afg.us.com timed out. (connect timeout=3)'))
# Error fetching https://www.collectioni.com/products/noahs-ark-lounge-swivel-chair: HTTPSConnectionPool(host='www.collectioni.com', port=443): Max retries exceeded with url: /products/noahs-ark-lounge-swivel-chair (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb0805b9b10>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error fetching https://noho.co/products/noho-move-chair-topper: 404 Client Error: Not Found for url: https://noho.co/products/noho-move-chair-topper
# Error fetching https://odafurniture.com/products/: HTTPSConnectionPool(host='odafurniture.com', port=443): Read timed out. (read timeout=3)
# Error fetching https://savannahspace.com/products/bo-woven-rug: 404 Client Error: Not Found for url: https://savannahspace.com/products/bo-woven-rug
# https://squarehome.com/products/
# Dining tables, chairs, sideboards, highboards... PRODUCT
# Error fetching https://www.sundays-company.com/collections/new-arrivals/products/sink-in-sofa-ecru: 404 Client Error: Not Found for url: https://www.sundays-company.com/collections/new-arrivals/products/sink-in-sofa-ecru
# https://thebeachfurniture.com.au/products/gift-card
# Beach Furniture PRODUCT
# Pots & Planters PRODUCT
# Abaca Basket - Large PRODUCT
# Abaca Basket - Small PRODUCT
# Bukumba Hanging Lamp - Small PRODUCT
# Error fetching https://thedesigndepot.co.nz/products/: 404 Client Error: Not Found for url: https://thedesigndepot.co.nz/products/
# Error fetching https://superdealfurnituregallery.com/products/tristan-5-piece-kitchen-set: 404 Client Error: Not Found for url: https://sdfgallery.ca/products/tristan-5-piece-kitchen-set
# https://signaturefinefurniture.ca/products/jacobson-bed
# Signature Woodworking Furniture PRODUCT
# Custom Furniture PRODUCT
# Woodworking Workshops or Classes PRODUCT
# Error fetching http://aonefurniture.in/userdata/products/no%20value: HTTPConnectionPool(host='aonefurniture.in', port=80): Max retries exceeded with url: /userdata/products/no%20value (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7fb0770651e0>, 'Connection to aonefurniture.in timed out. (connect timeout=3)'))
# Error fetching https://furnituremama.com/products/three-door-wardrobe-mirror-2: HTTPSConnectionPool(host='furnituremama.com', port=443): Read timed out. (read timeout=3)
# https://gfurniture.ca/products/
# Quality Furniture in Windsor PRODUCT
# CURIOS AND ETAGERES CURIOS AND ETAGERES CURIOS AND ETAGERES CURIOS AND ETAGERES CURIOS AND ETAGERES CURIOS AND ETAGERES CURIOS AND ETAGERES DINING ROOMS DINING ROOMS DINING ROOMS DINING ROOMS DINING ROOMS DINING ROOMS DINING ROOMS DINING ROOMS DINING ROOMS DINING ROOMS DINING ROOMS DINING ROOMS DINING ROOMS DINING ROOMS DINING ROOMS DINING ROOMS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS CONSOLE AND CREDENZAS Frequently Asked Questions PRODUCT
# Error fetching https://www.mwfurnitureoutlet.com/products/dresser: HTTPSConnectionPool(host='www.mwfurnitureoutlet.com', port=443): Max retries exceeded with url: /products/dresser (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb0805e84c0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))

# %% [markdown]
# I've learned a lot of new things while trying to create this project. I'm really glad I stuck with it! There were definitely some challenges along the way, but figuring out how to extract data from websites and how to train an NER module using spaCy really helped me improve my problem-solving skills and my vision about ML/AI. Now I feel much more confident tackling complex tasks.
